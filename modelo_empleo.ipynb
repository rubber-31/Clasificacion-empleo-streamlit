# %%
# ==========================================================
# MACHINE LEARNING - RANDOM FOREST
# Predicción del Empleo Formal e Informal
# ==========================================================

import pandas as pd
import numpy as np
import joblib

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    accuracy_score
)
# Out:
# Running cells with 'Python 3.13.7' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Usuario/Downloads/Empleo/.venv/Scripts/python.exe -m pip install ipykernel -U --user --force-reinstall'
